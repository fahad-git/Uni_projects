# %%
import os, shutil

original_dataset_dir = 'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc'
base_dir = 'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc-model'

if not os.path.exists(base_dir):
    os.mkdir(base_dir)

# %%
#'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc-model\train'
train_dir = os.path.join(base_dir, 'train')
if not os.path.exists(train_dir):
    os.mkdir(train_dir)
    #os.mkdirs(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
if not os.path.exists(validation_dir):
    os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
if not os.path.exists(test_dir):
    os.mkdir(test_dir)
    
    
# base
# train
# test 
# val

train_obj1_dir = os.path.join(train_dir, 'obj1')
if not os.path.exists(train_obj1_dir):
    os.mkdir(train_obj1_dir)

# 'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc-model\train\obj1'
    
train_obj2_dir = os.path.join(train_dir, 'obj2')
if not os.path.exists(train_obj2_dir):
    os.mkdir(train_obj2_dir)
    
train_obj3_dir = os.path.join(train_dir, 'obj3')
if not os.path.exists(train_obj3_dir):
    os.mkdir(train_obj3_dir)

train_obj4_dir = os.path.join(train_dir, 'obj4')
if not os.path.exists(train_obj4_dir):
    os.mkdir(train_obj4_dir)

train_obj5_dir = os.path.join(train_dir, 'obj5')
if not os.path.exists(train_obj5_dir):
    os.mkdir(train_obj5_dir)

# train /obj1,obj2,obj3,obj4,obj5
# src / imagename
# dest = train_obj5_dir/imagename
# shutile.copyfile(src,dst)

validation_obj1_dir = os.path.join(validation_dir, 'obj1')
if not os.path.exists(validation_obj1_dir):
    os.mkdir(validation_obj1_dir)

validation_obj2_dir = os.path.join(validation_dir, 'obj2')
if not os.path.exists(validation_obj2_dir):
    os.mkdir(validation_obj2_dir) 

validation_obj3_dir = os.path.join(validation_dir, 'obj3')
if not os.path.exists(validation_obj3_dir):
    os.mkdir(validation_obj3_dir)

validation_obj4_dir = os.path.join(validation_dir, 'obj4')
if not os.path.exists(validation_obj4_dir):
    os.mkdir(validation_obj4_dir) 

validation_obj5_dir = os.path.join(validation_dir, 'obj5')
if not os.path.exists(validation_obj5_dir):
    os.mkdir(validation_obj5_dir)


    
test_obj1_dir = os.path.join(test_dir, 'obj1')
if not os.path.exists(test_obj1_dir):
    os.mkdir(test_obj1_dir)

test_obj2_dir = os.path.join(test_dir, 'obj2')
if not os.path.exists(test_obj2_dir):
    os.mkdir(test_obj2_dir)

    
test_obj3_dir = os.path.join(test_dir, 'obj3')
if not os.path.exists(test_obj3_dir):
    os.mkdir(test_obj3_dir)

test_obj4_dir = os.path.join(test_dir, 'obj4')
if not os.path.exists(test_obj4_dir):
    os.mkdir(test_obj4_dir)
    
    
test_obj5_dir = os.path.join(test_dir, 'obj5')
if not os.path.exists(test_obj5_dir):
    os.mkdir(test_obj5_dir)

# %%
fnames = ['obj2__{}.png'.format(i) for i in range(41)]

# for i in range(41):
#     name[] ='obj2__{}.png'.format(i)
    # obj2__0.png
    # obj2__1.png
    # obj2__2.png

#fnames[0] = obj2__0.png
#fnames[1] = obj2__1.png
    
    
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_obj2_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

#     os.listdir(path) -- > list that contains names of subdir

    
# Copies the first
# 1,000 cat images
# to train_cats_dir

fnames = ['obj2__{}.png'.format(i) for i in range(41, 55)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_obj2_dir, fname)
#     if len(os.listdir(validation_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst) 
    
# Copies the next 500
# cat images to
# validation_cats_dir

fnames = ['obj2__{}.png'.format(i) for i in range(55, 72)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_obj2_dir, fname)
#     if len(os.listdir(test_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# %%
fnames = ['obj3__{}.png'.format(i) for i in range(41)]

for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_obj3_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# Copies the first
# 1,000 cat images
# to train_cats_dir

fnames = ['obj3__{}.png'.format(i) for i in range(41, 55)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_obj3_dir, fname)
#     if len(os.listdir(validation_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst) 
    
# Copies the next 500
# cat images to
# validation_cats_dir

fnames = ['obj3__{}.png'.format(i) for i in range(55, 72)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_obj3_dir, fname)
#     if len(os.listdir(test_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# %%
fnames = ['obj3__{}.png'.format(i) for i in range(41)]

for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_obj3_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# Copies the first
# 1,000 cat images
# to train_cats_dir

fnames = ['obj3__{}.png'.format(i) for i in range(41, 55)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_obj3_dir, fname)
#     if len(os.listdir(validation_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst) 
    
# Copies the next 500
# cat images to
# validation_cats_dir

fnames = ['obj3__{}.png'.format(i) for i in range(55, 72)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_obj3_dir, fname)
#     if len(os.listdir(test_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# %%
fnames = ['obj4__{}.png'.format(i) for i in range(41)]

for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_obj4_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# Copies the first
# 1,000 cat images
# to train_cats_dir

fnames = ['obj4__{}.png'.format(i) for i in range(41, 55)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_obj4_dir, fname)
#     if len(os.listdir(validation_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst) 
    
# Copies the next 500
# cat images to
# validation_cats_dir

fnames = ['obj4__{}.png'.format(i) for i in range(55, 72)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_obj4_dir, fname)
#     if len(os.listdir(test_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# %%
fnames = ['obj5__{}.png'.format(i) for i in range(41)]

for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_obj5_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# Copies the first
# 1,000 cat images
# to train_cats_dir

fnames = ['obj5__{}.png'.format(i) for i in range(41, 55)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_obj5_dir, fname)
#     if len(os.listdir(validation_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst) 
    
# Copies the next 500
# cat images to
# validation_cats_dir

fnames = ['obj5__{}.png'.format(i) for i in range(55, 72)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_obj5_dir, fname)
#     if len(os.listdir(test_obj1_dir)) > 0:
#         break;
    shutil.copyfile(src, dst)

# %%
print('\ntotal training obj1 images:', len(os.listdir(train_obj1_dir)))

print('\ntotal training obj2 images:', len(os.listdir(train_obj2_dir)))

print('\ntotal training obj3 images:', len(os.listdir(train_obj3_dir)))

print('\ntotal training obj4 images:', len(os.listdir(train_obj4_dir)))

print('\ntotal training obj5 images:', len(os.listdir(train_obj5_dir)))



print('\ntotal validation obj1 images:', len(os.listdir(validation_obj1_dir)))

print('\ntotal validation obj2 images:', len(os.listdir(validation_obj2_dir)))

print('\ntotal validation obj3 images:', len(os.listdir(validation_obj3_dir)))

print('\ntotal validation obj4 images:', len(os.listdir(validation_obj4_dir)))

print('\ntotal validation obj5 images:', len(os.listdir(validation_obj5_dir)))



print('\ntotal test obj1 images:', len(os.listdir(test_obj1_dir)))

print('\ntotal test obj2 images:', len(os.listdir(test_obj2_dir)))

print('\ntotal test obj3 images:', len(os.listdir(test_obj3_dir)))

print('\ntotal test obj4 images:', len(os.listdir(test_obj4_dir)))

print('\ntotal test obj5 images:', len(os.listdir(test_obj5_dir)))
# Out:
# total training obj1 images: 41
#
# total training obj2 images: 41
#
# total training obj3 images: 41
#
# total training obj4 images: 41
#
# total training obj5 images: 41
#
# total validation obj1 images: 14
#
# total validation obj2 images: 14
#
# total validation obj3 images: 14
#
# total validation obj4 images: 14
#
# total validation obj5 images: 14
#
# total test obj1 images: 17
#
# total test obj2 images: 17
#
# total test obj3 images: 17
#
# total test obj4 images: 17
#
# total test obj5 images: 17

# %%
from keras import layers
from keras import models
from keras import optimizers

model = models.Sequential()

# Linear model
# Filtering

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))

model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))

model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))

model.add(layers.MaxPooling2D((2, 2)))

# 6272

# Most related feature 

model.add(layers.Flatten())

model.add(layers.Dropout(0.5))

model.add(layers.Dense(512, activation='relu'))

# max(0,x)

model.add(layers.Dense(5, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(lr=1e-4),metrics=['acc'])

# Optimizers
# categorical_crossentropy
# binary_crossentropy
# Mean_squared_error
# sparse_categorical_crossentropy


#Loss Functions
# rmsprop
# adam

# %%
from keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# 1/255 * actual value

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')
# Out:
# Found 205 images belonging to 5 classes.
# Found 70 images belonging to 5 classes.

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=5,
      validation_data=validation_generator,
      validation_steps=50)

# History
# Train Loss
# Validation Loss
# Train Acc
# Val Acc
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# ...

# %%
model.save('coil-20-unproc.h5')

# Hierarchical Data Format 5 File

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# plt.plot(x, y-value, 'bo', label='Training acc')
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.models import load_model
import cv2
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = load_model('coil-20-unproc.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Fahad\Anaconda3\envs\Python36\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
img = cv2.imread('E:\\Study\\IBA BSCS-VIII\\Data Science\\coil-20-unproc-model\\test\\obj5\\obj5__56.png')
img = cv2.resize(img,(150,150))
img = np.reshape(img,[1,150, 150, 3])

# %%
predict = ["obj1","obj2","obj3","obj4","obj5"]
classes = model.predict_classes(img)
print(predict[classes[0]])
#print(predict[np.argmax(classes)])
# Out:
# obj5
