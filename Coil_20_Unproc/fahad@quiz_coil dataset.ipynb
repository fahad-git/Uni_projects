# %%
import os, shutil

original_dataset_dir = 'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc'
base_dir = 'E:\Study\IBA BSCS-VIII\Data Science\coil-20-unproc-quiz-augmented'

if not os.path.exists(base_dir):
    os.mkdir(base_dir)

# %%
obj1_dir = os.path.join(base_dir, 'obj1')
if not os.path.exists(obj1_dir):
    os.mkdir(obj1_dir)

obj2_dir = os.path.join(base_dir, 'obj2')
if not os.path.exists(obj2_dir):
    os.mkdir(obj2_dir) 

obj3_dir = os.path.join(base_dir, 'obj3')
if not os.path.exists(obj3_dir):
    os.mkdir(obj3_dir)

obj4_dir = os.path.join(base_dir, 'obj4')
if not os.path.exists(obj4_dir):
    os.mkdir(obj4_dir) 

obj5_dir = os.path.join(base_dir, 'obj5')
if not os.path.exists(obj5_dir):
    os.mkdir(obj5_dir)

# %%
import random
from scipy import ndarray

# image processing library
import skimage as sk
from skimage import transform
from skimage import util
from skimage import io



def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# dictionary of the transformations we defined earlier
available_transformations = {
    'rotate': random_rotation,
#     'horizontal_flip': horizontal_flip
    'flip': horizontal_flip
}

# Here we will define a function which will call all above functions
def augmentImage(command,arg):
    return available_transformations[command](arg)

# %%
fnames = ['obj1__{}.png'.format(i) for i in range(71)]

for fname in fnames:
    img_path = os.path.join(original_dataset_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    img_to_augment = sk.io.imread(img_path)
    img = ""
    name = ""
    
    rnd = random.randint(1,2)
    # Augmenting image
    if rnd == 1:
        img = augmentImage("flip",img_to_augment)
        name = "_flipped"+fname
    else:
        img = augmentImage("rotate",img_to_augment)
        name = "_rotated"+fname

    dst = os.path.join(obj1_dir, name)
        
    io.imsave(dst,img)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
fnames = ['obj2__{}.png'.format(i) for i in range(71)]

for fname in fnames:
    img_path = os.path.join(original_dataset_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    img_to_augment = sk.io.imread(img_path)
    img = ""
    name = ""
    
    rnd = random.randint(1,2)
    # Augmenting image
    if rnd == 1:
        img = augmentImage("flip",img_to_augment)
        name = "_flipped"+fname
    else:
        img = augmentImage("rotate",img_to_augment)
        name = "_rotated"+fname

    dst = os.path.join(obj2_dir, name)
        
    io.imsave(dst,img)
    
    
fnames = ['obj3__{}.png'.format(i) for i in range(71)]

for fname in fnames:
    img_path = os.path.join(original_dataset_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    img_to_augment = sk.io.imread(img_path)
    img = ""
    name = ""
    
    rnd = random.randint(1,2)
    # Augmenting image
    if rnd == 1:
        img = augmentImage("flip",img_to_augment)
        name = "_flipped"+fname
    else:
        img = augmentImage("rotate",img_to_augment)
        name = "_rotated"+fname

    dst = os.path.join(obj3_dir, name)
        
    io.imsave(dst,img)
    
    
    
fnames = ['obj4__{}.png'.format(i) for i in range(71)]

for fname in fnames:
    img_path = os.path.join(original_dataset_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    img_to_augment = sk.io.imread(img_path)
    img = ""
    name = ""
    
    rnd = random.randint(1,2)
    # Augmenting image
    if rnd == 1:
        img = augmentImage("flip",img_to_augment)
        name = "_flipped"+fname
    else:
        img = augmentImage("rotate",img_to_augment)
        name = "_rotated"+fname

    dst = os.path.join(obj4_dir, name)
        
    io.imsave(dst,img)
    
    
    
fnames = ['obj5__{}.png'.format(i) for i in range(71)]

for fname in fnames:
    img_path = os.path.join(original_dataset_dir, fname)
#     if len(os.listdir(train_obj1_dir)) > 0:
#         break;
    img_to_augment = sk.io.imread(img_path)
    img = ""
    name = ""
    
    rnd = random.randint(1,2)
    # Augmenting image
    if rnd == 1:
        img = augmentImage("flip",img_to_augment)
        name = "_flipped"+fname
    else:
        img = augmentImage("rotate",img_to_augment)
        name = "_rotated"+fname

    dst = os.path.join(obj5_dir, name)
        
    io.imsave(dst,img)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,5))

plt.margins(0.01)

classes = os.listdir(base_dir)
pos = np.arange(len(classes))
# pos
instances = []
for eachclass in classes:
    instance_path = os.path.join(base_dir,eachclass)
    instances.append(len(os.listdir(instance_path)))
    
plt.bar(classes, instances, align='center', alpha=0.5)
#plt.xticks(pos, classes,rotation='vertical',fontsize=10)
plt.ylabel('No of Instances')
plt.title('Object detection dataset')

plt.show()
